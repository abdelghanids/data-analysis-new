# %%
# Ignore all code warnings 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Olympics
#
# This is a historical dataset on the modern Olympic Games, from Athens 1896 to Rio 2016. Each row consists of an individual athlete competing in an Olympic event and which medal was won (if any).
#
# Not sure where to begin? Scroll to the bottom to find challenges!

# %%
import pandas as pd

olympic=pd.read_csv("Data/dataset.csv")

# %%
olympic.to_csv("dataset.csv")

# %% [markdown]
# ## Data Dictionary
#
# |Column   |Explanation                   |
# | ------- | ---------------------------- |
# |id       |Unique number for each athlete |
# |name     |Athlete's name                 |
# |sex      |M or F                         |
# |age      |Age of the athlete                        |
# |height   |In centimeters                 |
# |weight   |In kilograms                   |
# |team     |Team name                      |
# |noc      |National Olympic Committee 3   |
# |games    |Year and season                |
# |year     |Integer                        |
# |season   |Summer or Winter               |
# |city     |Host city                      |
# |sport    |Sport                          |
# |event    |Event                          |
# |medal    |Gold, Silver, Bronze, or NA    |

# %% [markdown]
# [Source](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results) and [license](https://creativecommons.org/publicdomain/zero/1.0/) of the dataset.
# The dataset is a consolidated version of data from www.sports-reference.com.

# %% [markdown]
# ## Don't know where to start?
#
# **Challenges are brief tasks designed to help you practice specific skills:**
#
# - 🗺️ **Explore**: In which year and city did the Netherlands win the highest number of medals in their history?
# - 📊 **Visualize**: Create a plot visualizing the relationship between the number of athletes countries send to an event and the number of medals they receive.
# - 🔎 **Analyze**: In which sports does the height of an athlete increase their chances of earning a medal?
#
# **Scenarios are broader questions to help you develop an end-to-end project for your portfolio:**
#
# You are working as a data analyst for an international judo club. The owner of the club is looking for new ways to leverage data for competition. One idea they have had is to use past competition data to estimate the threat of future opponents. They have provided you with a dataset of past Olympic data and want to know whether you can use information such as the height, weight, age, and national origin of a judo competitor to estimate the probability that they will earn a medal.
#
# You will need to prepare a report that is accessible to a broad audience. It should outline your steps, findings, and conclusions.
#
# ---
#
# ✍️ _If you have an idea for an interesting Scenario or Challenge, or have feedback on our existing ones, let us know! You can submit feedback by pressing the question mark in the top right corner of the screen and selecting "Give Feedback". Include the phrase "Content Feedback" to help us flag it in our system._

# %%
olympic.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1  id                      name sex   age  height  \
# 0           0             0   1                 A Dijiang   M  24.0   180.0
# 1           1             1   2                  A Lamusi   M  23.0   170.0
# 2           2             2   3       Gunnar Nielsen Aaby   M  24.0     NaN
# 3           3             3   4      Edgar Lindenau Aabye   M  34.0     NaN
# 4           4             4   5  Christine Jacoba Aaftink   F  21.0   185.0
# 5           5             5   5  Christine Jacoba Aaftink   F  21.0   185.0
# 6           6             6   5  Christine Jacoba Aaftink   F  25.0   185.0
# 7           7             7   5  Christine Jacoba Aaftink   F  25.0   185.0
# 8           8             8   5  Christine Jacoba Aaftink   F  27.0   185.0
# 9           9             9   5  Christine Jacoba Aaftink   F  27.0   185.0
#
#    weight            team  noc        games  year  season         city  \
# 0    80.0           China  CHN  1992 Summer  1992  Summer    Barcelona
# 1    60.0           China  CHN  2012 Summer  2012  Summer       London
# 2     NaN         Denmark  DEN  1920 Summer  1920  Summer    Antwerpen
# 3     NaN  Denmark/Sweden  DEN  1900 Summer  1900  Summer        Paris
# 4    82.0     Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 5    82.0     Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 6    82.0     Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 7    82.0     Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 8    82.0     Netherlands  NED  1994 Winter  1994  Winter  Lillehammer
# 9    82.0     Netherlands  NED  1994 Winter  1994  Winter  Lillehammer
#
#            sport                               event medal
# 0     Basketball         Basketball Men's Basketball   NaN
# 1           Judo        Judo Men's Extra-Lightweight   NaN
# 2       Football             Football Men's Football   NaN
# 3     Tug-Of-War         Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 6  Speed Skating    Speed Skating Women's 500 metres   NaN
# 7  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 8  Speed Skating    Speed Skating Women's 500 metres   NaN
# 9  Speed Skating  Speed Skating Women's 1,000 metres   NaN

# %%
olympic.shape
#(line,colone)
# Out:
# (271116, 17)

# %%
olympic.describe(include='all')
# Out:
#            Unnamed: 0   Unnamed: 0.1             id                  name  \
# count   271116.000000  271116.000000  271116.000000                271116
# unique            NaN            NaN            NaN                134731
# top               NaN            NaN            NaN  Robert Tait McKenzie
# freq              NaN            NaN            NaN                    58
# mean    135557.500000  135557.500000   68248.954396                   NaN
# std      78264.592128   78264.592128   39022.286345                   NaN
# min          0.000000       0.000000       1.000000                   NaN
# 25%      67778.750000   67778.750000   34643.000000                   NaN
# 50%     135557.500000  135557.500000   68205.000000                   NaN
# 75%     203336.250000  203336.250000  102097.250000                   NaN
# max     271115.000000  271115.000000  135571.000000                   NaN
#
#            sex            age         height         weight           team  \
# count   271116  261642.000000  210945.000000  208241.000000         271116
# unique       2            NaN            NaN            NaN           1184
# top          M            NaN            NaN            NaN  United States
# freq    196594            NaN            NaN            NaN          17847
# mean       NaN      25.556898     175.338970      70.702393            NaN
# std        NaN       6.393561      10.518462      14.348020            NaN
# min        NaN      10.000000     127.000000      25.000000            NaN
# 25%        NaN      21.000000     168.000000      60.000000            NaN
# 50%        NaN      24.000000     175.000000      70.000000            NaN
# 75%        NaN      28.000000     183.000000      79.000000            NaN
# max        NaN      97.000000     226.000000     214.000000            NaN
#
#            noc        games           year  season    city      sport  \
# count   271116       271116  271116.000000  271116  271116     271116
# unique     230           51            NaN       2      42         66
# top        USA  2000 Summer            NaN  Summer  London  Athletics
# freq     18853        13821            NaN  222552   22426      38624
# mean       NaN          NaN    1978.378480     NaN     NaN        NaN
# std        NaN          NaN      29.877632     NaN     NaN        NaN
# min        NaN          NaN    1896.000000     NaN     NaN        NaN
# 25%        NaN          NaN    1960.000000     NaN     NaN        NaN
# 50%        NaN          NaN    1988.000000     NaN     NaN        NaN
# 75%        NaN          NaN    2002.000000     NaN     NaN        NaN
# max        NaN          NaN    2016.000000     NaN     NaN        NaN
#
#                           event  medal
# count                    271116  39783
# unique                      765      3
# top     Football Men's Football   Gold
# freq                       5733  13372
# mean                        NaN    NaN
# std                         NaN    NaN
# min                         NaN    NaN
# 25%                         NaN    NaN
# 50%                         NaN    NaN
# 75%                         NaN    NaN
# max                         NaN    NaN

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    271116 non-null  int64
#  1   Unnamed: 0.1  271116 non-null  int64
#  2   id            271116 non-null  int64
#  3   name          271116 non-null  object
#  4   sex           271116 non-null  object
#  5   age           261642 non-null  float64
#  6   height        210945 non-null  float64
#  7   weight        208241 non-null  float64
#  8   team          271116 non-null  object
#  9   noc           271116 non-null  object
#  10  games         271116 non-null  object
#  11  year          271116 non-null  int64
#  12  season        271116 non-null  object
#  13  city          271116 non-null  object
#  14  sport         271116 non-null  object
#  15  event         271116 non-null  object
#  16  medal         39783 non-null   object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 35.2+ MB

# %% [markdown]
# ## selectionner que les joueurs de Netherlands

# %%
Neth_olympic=olympic[olympic.team=="Netherlands"]
Neth_olympic.head(5)
# Out:
#    Unnamed: 0  Unnamed: 0.1  id                      name sex   age  height  \
# 4           4             4   5  Christine Jacoba Aaftink   F  21.0   185.0
# 5           5             5   5  Christine Jacoba Aaftink   F  21.0   185.0
# 6           6             6   5  Christine Jacoba Aaftink   F  25.0   185.0
# 7           7             7   5  Christine Jacoba Aaftink   F  25.0   185.0
# 8           8             8   5  Christine Jacoba Aaftink   F  27.0   185.0
#
#    weight         team  noc        games  year  season         city  \
# 4    82.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 5    82.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 6    82.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 7    82.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 8    82.0  Netherlands  NED  1994 Winter  1994  Winter  Lillehammer
#
#            sport                               event medal
# 4  Speed Skating    Speed Skating Women's 500 metres   NaN
# 5  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 6  Speed Skating    Speed Skating Women's 500 metres   NaN
# 7  Speed Skating  Speed Skating Women's 1,000 metres   NaN
# 8  Speed Skating    Speed Skating Women's 500 metres   NaN

# %% [markdown]
# #### Gestion des données manquantes
# * Il manque certaines informations.
#     * déterminer les cases vides
#     * remplir les cases par des valeurs aliatoires (tant que on ne pas besoin de donnée de pods et taille)

# %% [markdown]
# ### déterminer les cases vides

# %%
Neth_olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5718 entries, 4 to 271051
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    5718 non-null   int64
#  1   Unnamed: 0.1  5718 non-null   int64
#  2   id            5718 non-null   int64
#  3   name          5718 non-null   object
#  4   sex           5718 non-null   object
#  5   age           5713 non-null   float64
#  6   height        3733 non-null   float64
#  7   weight        3695 non-null   float64
#  8   team          5718 non-null   object
#  9   noc           5718 non-null   object
#  10  games         5718 non-null   object
#  11  year          5718 non-null   int64
#  12  season        5718 non-null   object
#  13  city          5718 non-null   object
#  14  sport         5718 non-null   object
#  15  event         5718 non-null   object
#  16  medal         988 non-null    object
# dtypes: float64(3), int64(4), object(10)
# memory usage: 804.1+ KB

# %% [markdown]
# ### determinier le manque de donnée pour le poid

# %%
Neth_olympic["weight"].describe()
# Out:
# count    3695.000000
# mean       73.512855
# std        13.116757
# min        38.000000
# 25%        64.000000
# 50%        73.000000
# 75%        82.000000
# max       135.000000
# Name: weight, dtype: float64

# %%
neth_weight=Neth_olympic.fillna(value={"weight": min})

# %% [markdown]
#  :muscle:
#  ### Déterminier le manque de donnée pour la taille

# %%
Neth_olympic["height"].describe()
# Out:
# count    3733.000000
# mean      179.452987
# std         9.970414
# min       147.000000
# 25%       172.000000
# 50%       180.000000
# 75%       186.000000
# max       213.000000
# Name: height, dtype: float64

# %%
neth_height=neth_weight.fillna(value={"weight": min})

# %% [markdown]
# déterminer les données manquantes de poids

# %%
neth_age=neth_weight.fillna(value={"age": min})

# %%
neth_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5718 entries, 4 to 271051
# Data columns (total 17 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    5718 non-null   int64
#  1   Unnamed: 0.1  5718 non-null   int64
#  2   id            5718 non-null   int64
#  3   name          5718 non-null   object
#  4   sex           5718 non-null   object
#  5   age           5718 non-null   object
#  6   height        3733 non-null   float64
#  7   weight        5718 non-null   object
#  8   team          5718 non-null   object
#  9   noc           5718 non-null   object
#  10  games         5718 non-null   object
#  11  year          5718 non-null   int64
#  12  season        5718 non-null   object
#  13  city          5718 non-null   object
#  14  sport         5718 non-null   object
#  15  event         5718 non-null   object
#  16  medal         988 non-null    object
# dtypes: float64(1), int64(4), object(12)
# memory usage: 804.1+ KB

# %% [markdown]
# Maintenant on va créer une nouvelle colonne boolenne qui transforme la resultat de medal si l'équipe avoir une medal on avoir true pour facilité le calcul de la somme de medal

# %%
neth_olympic1.head(5)
# Out:
#       Unnamed: 0    id                name sex   age  height weight  \
# 92            92    30    Pepijn Aardewijn   M  26.0   189.0   72.0
# 1227        1227   690  Chantal Achterberg   F  27.0   172.0   72.0
# 1228        1228   690  Chantal Achterberg   F  31.0   172.0   72.0
# 2099        2099  1169    Marilyn Agliotti   F  29.0   172.0   58.0
# 2100        2100  1169    Marilyn Agliotti   F  33.0   172.0   58.0
#
#              team  noc        games  year  season            city   sport  \
# 92    Netherlands  NED  1996 Summer  1996  Summer         Atlanta  Rowing
# 1227  Netherlands  NED  2012 Summer  2012  Summer          London  Rowing
# 1228  Netherlands  NED  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 2099  Netherlands  NED  2008 Summer  2008  Summer         Beijing  Hockey
# 2100  Netherlands  NED  2012 Summer  2012  Summer          London  Hockey
#
#                                        event   medal   gold  silver  bronze
# 92    Rowing Men's Lightweight Double Sculls  Silver  False    True   False
# 1227             Rowing Women's Coxed Eights  Bronze  False   False    True
# 1228         Rowing Women's Quadruple Sculls  Silver  False    True   False
# 2099                   Hockey Women's Hockey    Gold   True   False   False
# 2100                   Hockey Women's Hockey    Gold   True   False   False

# %%
nb_gold_medal= neth_olympic1.groupby(['year'])['gold'].sum()
nb_gold_medal.head(5)
# Out:
# year
# 1924    0
# 1928    3
# 1932    1
# 1936    1
# 1948    4
# Name: gold, dtype: int64

# %%
nb_gold_medal.plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %%
nb_silver_medal= neth_olympic1.groupby(['year'])['silver'].sum()
nb_silver_medal.head(5)
# Out:
# year
# 1924    0
# 1928    2
# 1932    7
# 1936    1
# 1948    0
# Name: silver, dtype: int64

# %%
nb_silver_medal.plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %%
nb_bronze_medal= neth_olympic1.groupby(['year'])['bronze'].sum()
nb_bronze_medal.head(5)
# Out:
# year
# 1924    1
# 1928    0
# 1932    0
# 1936    2
# 1948    2
# Name: bronze, dtype: int64

# %%
nb_bronze_medal.plot()
# Out:
# C:\Users\wajih\AppData\Roaming\Python\Python38\site-packages\mpl_toolkits\mplot3d\__init__.py:1: MatplotlibDeprecationWarning:
# The deprecated function was deprecated in Matplotlib 3.4 and will be removed two minor releases later.
#   from .axes3d import Axes3D
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# * Construire une nouvelle dataset

# %%
# build the general dataset Medal/Year
new = { 
   "bronze_medal":nb_bronze_medal,
   "silver_medal":nb_silver_medal ,
   "gold_medal":nb_gold_medal,
   "total_medal":nb_gold_medal+nb_silver_medal+nb_bronze_medal
}

new_df_1 = pd.DataFrame(new).reset_index()

new_df_1.head(5)
# Out:
#    year  bronze_medal  silver_medal  gold_medal  total_medal
# 0  1924             1             0           0            1
# 1  1928             0             2           3            5
# 2  1932             0             7           1            8
# 3  1936             2             1           1            4
# 4  1948             2             0           4            6

# %%
# build the specified dataset Year/City/Medal
new_df_2 = neth_olympic1.groupby(['year','city'])['bronze','silver','gold'].sum().reset_index() # group by city and year 
new_df_2['total_medal'] = new_df_2['gold'] + new_df_2['silver'] + new_df_2['bronze'] # Calculate the total of medals
new_df_2 = new_df_2.rename({'bronze': 'bronze_medal', 'silver': 'silver_medal', 'gold': 'gold_medal'}, axis='columns') # rename the columns 
new_df_2.head(5)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_3224\2317760414.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_df_2 = neth_olympic1.groupby(['year','city'])['bronze','silver','gold'].sum().reset_index() # group by city and year
#    year         city  bronze_medal  silver_medal  gold_medal  total_medal
# 0  1924        Paris             1             0           0            1
# 1  1928    Amsterdam             0             2           3            5
# 2  1932  Los Angeles             0             7           1            8
# 3  1936       Berlin             2             1           1            4
# 4  1948       London             2             0           4            6

# %% [markdown]
# Le maximum de medal qui etait prise par holand

# %%
# First method (return the city that has the max number of total medals)
last=new_df_2.loc[new_df_2['total_medal'] == max(new_df_2['total_medal'])]

# %%
# Second method 
new_df_2.iloc[new_df_2['total_medal'].idxmax()]
# Out:
# year              2000
# city            Sydney
# bronze_medal        23
# silver_medal        29
# gold_medal          27
# total_medal         79
# Name: 26, dtype: object

# %%
# return the city that has the max number of gold medals
new_df_2.loc[new_df_2['gold_medal'] == max(new_df_2['gold_medal'])]
# Out:
#     year     city  bronze_medal  silver_medal  gold_medal  total_medal
# 30  2008  Beijing             4            15          39           58
