# %%
# Ignore all code warnings 
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # Olympics
#
# This is a historical dataset on the modern Olympic Games, from Athens 1896 to Rio 2016. Each row consists of an individual athlete competing in an Olympic event and which medal was won (if any).
#
# Not sure where to begin? Scroll to the bottom to find challenges!

# %%
import pandas as pd

olympic=pd.read_csv("Data/dataset.csv")

# %%
olympic.to_csv("dataset.csv")

# %% [markdown]
# ## Data Dictionary
#
# |Column   |Explanation                   |
# | ------- | ---------------------------- |
# |id       |Unique number for each athlete |
# |name     |Athlete's name                 |
# |sex      |M or F                         |
# |age      |Age of the athlete                        |
# |height   |In centimeters                 |
# |weight   |In kilograms                   |
# |team     |Team name                      |
# |noc      |National Olympic Committee 3   |
# |games    |Year and season                |
# |year     |Integer                        |
# |season   |Summer or Winter               |
# |city     |Host city                      |
# |sport    |Sport                          |
# |event    |Event                          |
# |medal    |Gold, Silver, Bronze, or NA    |

# %% [markdown]
# [Source](https://www.kaggle.com/heesoo37/120-years-of-olympic-history-athletes-and-results) and [license](https://creativecommons.org/publicdomain/zero/1.0/) of the dataset.
# The dataset is a consolidated version of data from www.sports-reference.com.

# %% [markdown]
# ## Don't know where to start?
#
# **Challenges are brief tasks designed to help you practice specific skills:**
#
# - 🗺️ **Explore**: In which year and city did the Netherlands win the highest number of medals in their history?
# - 📊 **Visualize**: Create a plot visualizing the relationship between the number of athletes countries send to an event and the number of medals they receive.
# - 🔎 **Analyze**: In which sports does the height of an athlete increase their chances of earning a medal?
#
# **Scenarios are broader questions to help you develop an end-to-end project for your portfolio:**
#
# You are working as a data analyst for an international judo club. The owner of the club is looking for new ways to leverage data for competition. One idea they have had is to use past competition data to estimate the threat of future opponents. They have provided you with a dataset of past Olympic data and want to know whether you can use information such as the height, weight, age, and national origin of a judo competitor to estimate the probability that they will earn a medal.
#
# You will need to prepare a report that is accessible to a broad audience. It should outline your steps, findings, and conclusions.
#
# ---
#
# ✍️ _If you have an idea for an interesting Scenario or Challenge, or have feedback on our existing ones, let us know! You can submit feedback by pressing the question mark in the top right corner of the screen and selecting "Give Feedback". Include the phrase "Content Feedback" to help us flag it in our system._

# %%
olympic.head(5)
# Out:
#    Unnamed: 0  id                      name sex   age  height  weight  \
# 0           0   1                 A Dijiang   M  24.0   180.0    80.0
# 1           1   2                  A Lamusi   M  23.0   170.0    60.0
# 2           2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3           3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4           4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
#
#              team  noc        games  year  season       city          sport  \
# 0           China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1           China  CHN  2012 Summer  2012  Summer     London           Judo
# 2         Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4     Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               event medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
print(olympic.head(5).to_markdown())
# Out:
# |    |   Unnamed: 0 |   id | name                     | sex   |   age |   height |   weight | team           | noc   | games       |   year | season   | city      | sport         | event                            | medal   |
# |---:|-------------:|-----:|:-------------------------|:------|------:|---------:|---------:|:---------------|:------|:------------|-------:|:---------|:----------|:--------------|:---------------------------------|:--------|
# |  0 |            0 |    1 | A Dijiang                | M     |    24 |      180 |       80 | China          | CHN   | 1992 Summer |   1992 | Summer   | Barcelona | Basketball    | Basketball Men's Basketball      | nan     |
# |  1 |            1 |    2 | A Lamusi                 | M     |    23 |      170 |       60 | China          | CHN   | 2012 Summer |   2012 | Summer   | London    | Judo          | Judo Men's Extra-Lightweight     | nan     |
# |  2 |            2 |    3 | Gunnar Nielsen Aaby      | M     |    24 |      nan |      nan | Denmark        | DEN   | 1920 Summer |   1920 | Summer   | Antwerpen | Football      | Football Men's Football          | nan     |
# |  3 |            3 |    4 | Edgar Lindenau Aabye     | M     |    34 |      nan |      nan | Denmark/Sweden | DEN   | 1900 Summer |   1900 | Summer   | Paris     | Tug-Of-War    | Tug-Of-War Men's Tug-Of-War      | Gold    |
# |  4 |            4 |    5 | Christine Jacoba Aaftink | F     |    21 |      185 |       82 | Netherlands    | NED   | 1988 Winter |   1988 | Winter   | Calgary   | Speed Skating | Speed Skating Women's 500 metres | nan     |

# %%
olympic.shape
#(line,colone)
# Out:
# (271116, 16)

# %%
olympic.describe(include='all')
# Out:
#            Unnamed: 0             id                  name     sex  \
# count   271116.000000  271116.000000                271116  271116
# unique            NaN            NaN                134731       2
# top               NaN            NaN  Robert Tait McKenzie       M
# freq              NaN            NaN                    58  196594
# mean    135557.500000   68248.954396                   NaN     NaN
# std      78264.592128   39022.286345                   NaN     NaN
# min          0.000000       1.000000                   NaN     NaN
# 25%      67778.750000   34643.000000                   NaN     NaN
# 50%     135557.500000   68205.000000                   NaN     NaN
# 75%     203336.250000  102097.250000                   NaN     NaN
# max     271115.000000  135571.000000                   NaN     NaN
#
#                   age         height         weight           team     noc  \
# count   261642.000000  210945.000000  208241.000000         271116  271116
# unique            NaN            NaN            NaN           1184     230
# top               NaN            NaN            NaN  United States     USA
# freq              NaN            NaN            NaN          17847   18853
# mean        25.556898     175.338970      70.702393            NaN     NaN
# std          6.393561      10.518462      14.348020            NaN     NaN
# min         10.000000     127.000000      25.000000            NaN     NaN
# 25%         21.000000     168.000000      60.000000            NaN     NaN
# 50%         24.000000     175.000000      70.000000            NaN     NaN
# 75%         28.000000     183.000000      79.000000            NaN     NaN
# max         97.000000     226.000000     214.000000            NaN     NaN
#
#               games           year  season    city      sport  \
# count        271116  271116.000000  271116  271116     271116
# unique           51            NaN       2      42         66
# top     2000 Summer            NaN  Summer  London  Athletics
# freq          13821            NaN  222552   22426      38624
# mean            NaN    1978.378480     NaN     NaN        NaN
# std             NaN      29.877632     NaN     NaN        NaN
# min             NaN    1896.000000     NaN     NaN        NaN
# 25%             NaN    1960.000000     NaN     NaN        NaN
# 50%             NaN    1988.000000     NaN     NaN        NaN
# 75%             NaN    2002.000000     NaN     NaN        NaN
# max             NaN    2016.000000     NaN     NaN        NaN
#
#                           event  medal
# count                    271116  39783
# unique                      765      3
# top     Football Men's Football   Gold
# freq                       5733  13372
# mean                        NaN    NaN
# std                         NaN    NaN
# min                         NaN    NaN
# 25%                         NaN    NaN
# 50%                         NaN    NaN
# 75%                         NaN    NaN
# max                         NaN    NaN

# %%
olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  271116 non-null  int64
#  1   id          271116 non-null  int64
#  2   name        271116 non-null  object
#  3   sex         271116 non-null  object
#  4   age         261642 non-null  float64
#  5   height      210945 non-null  float64
#  6   weight      208241 non-null  float64
#  7   team        271116 non-null  object
#  8   noc         271116 non-null  object
#  9   games       271116 non-null  object
#  10  year        271116 non-null  int64
#  11  season      271116 non-null  object
#  12  city        271116 non-null  object
#  13  sport       271116 non-null  object
#  14  event       271116 non-null  object
#  15  medal       39783 non-null   object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 33.1+ MB

# %% [markdown]
# ## selectionner que les joueurs de Netherlands

# %%
Neth_olympic=olympic[olympic.team=="Netherlands"]
Neth_olympic.head(10)
# Out:
#     Unnamed: 0  id                                name sex   age  height  \
# 4            4   5            Christine Jacoba Aaftink   F  21.0   185.0
# 5            5   5            Christine Jacoba Aaftink   F  21.0   185.0
# 6            6   5            Christine Jacoba Aaftink   F  25.0   185.0
# 7            7   5            Christine Jacoba Aaftink   F  25.0   185.0
# 8            8   5            Christine Jacoba Aaftink   F  27.0   185.0
# 9            9   5            Christine Jacoba Aaftink   F  27.0   185.0
# 26          26   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0
# 27          27   8  Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0
# 88          88  27                       Johan Aantjes   M  26.0     NaN
# 91          91  29                Willemien Aardenburg   F  22.0     NaN
#
#     weight         team  noc        games  year  season         city  \
# 4     82.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 5     82.0  Netherlands  NED  1988 Winter  1988  Winter      Calgary
# 6     82.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 7     82.0  Netherlands  NED  1992 Winter  1992  Winter  Albertville
# 8     82.0  Netherlands  NED  1994 Winter  1994  Winter  Lillehammer
# 9     82.0  Netherlands  NED  1994 Winter  1994  Winter  Lillehammer
# 26     NaN  Netherlands  NED  1932 Summer  1932  Summer  Los Angeles
# 27     NaN  Netherlands  NED  1932 Summer  1932  Summer  Los Angeles
# 88     NaN  Netherlands  NED  1984 Summer  1984  Summer  Los Angeles
# 91     NaN  Netherlands  NED  1988 Summer  1988  Summer        Seoul
#
#             sport                                   event   medal
# 4   Speed Skating        Speed Skating Women's 500 metres     NaN
# 5   Speed Skating      Speed Skating Women's 1,000 metres     NaN
# 6   Speed Skating        Speed Skating Women's 500 metres     NaN
# 7   Speed Skating      Speed Skating Women's 1,000 metres     NaN
# 8   Speed Skating        Speed Skating Women's 500 metres     NaN
# 9   Speed Skating      Speed Skating Women's 1,000 metres     NaN
# 26      Athletics            Athletics Women's 100 metres     NaN
# 27      Athletics  Athletics Women's 4 x 100 metres Relay     NaN
# 88     Water Polo             Water Polo Men's Water Polo     NaN
# 91         Hockey                   Hockey Women's Hockey  Bronze

# %% [markdown]
# #### Gestion des données manquantes
# * Il manque certaines informations.
#     * déterminer les cases vides
#     * remplir les cases par des valeurs aliatoires (tant que on ne pas besoin de donnée de pods et taille)

# %% [markdown]
# ### déterminer les cases vides

# %%
Neth_olympic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5718 entries, 4 to 271051
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5718 non-null   int64
#  1   id          5718 non-null   int64
#  2   name        5718 non-null   object
#  3   sex         5718 non-null   object
#  4   age         5713 non-null   float64
#  5   height      3733 non-null   float64
#  6   weight      3695 non-null   float64
#  7   team        5718 non-null   object
#  8   noc         5718 non-null   object
#  9   games       5718 non-null   object
#  10  year        5718 non-null   int64
#  11  season      5718 non-null   object
#  12  city        5718 non-null   object
#  13  sport       5718 non-null   object
#  14  event       5718 non-null   object
#  15  medal       988 non-null    object
# dtypes: float64(3), int64(3), object(10)
# memory usage: 759.4+ KB

# %% [markdown]
# ### determinier le manque de donnée pour le poid

# %%
Neth_olympic["weight"].describe()
# Out:
# count    3695.000000
# mean       73.512855
# std        13.116757
# min        38.000000
# 25%        64.000000
# 50%        73.000000
# 75%        82.000000
# max       135.000000
# Name: weight, dtype: float64

# %%
neth_weight=Neth_olympic.fillna(value={"weight": min})

# %% [markdown]
#  :muscle:
#  ### Déterminier le manque de donnée pour la taille

# %%
Neth_olympic["height"].describe()
# Out:
# count    3733.000000
# mean      179.452987
# std         9.970414
# min       147.000000
# 25%       172.000000
# 50%       180.000000
# 75%       186.000000
# max       213.000000
# Name: height, dtype: float64

# %%
neth_height=neth_weight.fillna(value={"weight": min})

# %% [markdown]
# déterminer les données manquantes de poids

# %%
neth_age=neth_weight.fillna(value={"age": min})

# %%
neth_age.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5718 entries, 4 to 271051
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5718 non-null   int64
#  1   id          5718 non-null   int64
#  2   name        5718 non-null   object
#  3   sex         5718 non-null   object
#  4   age         5718 non-null   object
#  5   height      3733 non-null   float64
#  6   weight      5718 non-null   object
#  7   team        5718 non-null   object
#  8   noc         5718 non-null   object
#  9   games       5718 non-null   object
#  10  year        5718 non-null   int64
#  11  season      5718 non-null   object
#  12  city        5718 non-null   object
#  13  sport       5718 non-null   object
#  14  event       5718 non-null   object
#  15  medal       988 non-null    object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 759.4+ KB

# %%
neth_olympic1=neth_age.dropna()
neth_olympic1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 716 entries, 92 to 271049
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  716 non-null    int64
#  1   id          716 non-null    int64
#  2   name        716 non-null    object
#  3   sex         716 non-null    object
#  4   age         716 non-null    object
#  5   height      716 non-null    float64
#  6   weight      716 non-null    object
#  7   team        716 non-null    object
#  8   noc         716 non-null    object
#  9   games       716 non-null    object
#  10  year        716 non-null    int64
#  11  season      716 non-null    object
#  12  city        716 non-null    object
#  13  sport       716 non-null    object
#  14  event       716 non-null    object
#  15  medal       716 non-null    object
# dtypes: float64(1), int64(3), object(12)
# memory usage: 95.1+ KB

# %% [markdown]
# Maintenant on va créer une nouvelle colonne boolenne qui transforme la resultat de medal si l'équipe avoir une medal on avoir true pour facilité le calcul de la somme de medal

# %%
neth_olympic1['gold']=neth_olympic1['medal']=='Gold'
neth_olympic1['silver']=neth_olympic1['medal']=='Silver'
neth_olympic1['bronze']=neth_olympic1['medal']=='Bronze'
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20212\3201187883.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neth_olympic1['gold']=neth_olympic1['medal']=='Gold'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20212\3201187883.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neth_olympic1['silver']=neth_olympic1['medal']=='Silver'
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_20212\3201187883.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   neth_olympic1['bronze']=neth_olympic1['medal']=='Bronze'

# %%
neth_olympic1.head(10)
# Out:
#        Unnamed: 0    id                                      name sex   age  \
# 92             92    30                          Pepijn Aardewijn   M  26.0
# 1227         1227   690                        Chantal Achterberg   F  27.0
# 1228         1228   690                        Chantal Achterberg   F  31.0
# 2099         2099  1169                          Marilyn Agliotti   F  29.0
# 2100         2100  1169                          Marilyn Agliotti   F  33.0
# 8596         8596  4720                          Tessa Appeldoorn   F  27.0
# 11720       11720  6397           Alexander German "Sander" Baart   M  24.0
# 11724       11724  6398  Christina Wilhelmina "Stien" Baas-Kaiser   F  29.0
# 11725       11725  6398  Christina Wilhelmina "Stien" Baas-Kaiser   F  29.0
# 11726       11726  6398  Christina Wilhelmina "Stien" Baas-Kaiser   F  33.0
#
#        height weight         team  noc        games  year  season  \
# 92      189.0   72.0  Netherlands  NED  1996 Summer  1996  Summer
# 1227    172.0   72.0  Netherlands  NED  2012 Summer  2012  Summer
# 1228    172.0   72.0  Netherlands  NED  2016 Summer  2016  Summer
# 2099    172.0   58.0  Netherlands  NED  2008 Summer  2008  Summer
# 2100    172.0   58.0  Netherlands  NED  2012 Summer  2012  Summer
# 8596    177.0   71.0  Netherlands  NED  2000 Summer  2000  Summer
# 11720   178.0   76.0  Netherlands  NED  2012 Summer  2012  Summer
# 11724   174.0   69.0  Netherlands  NED  1968 Winter  1968  Winter
# 11725   174.0   69.0  Netherlands  NED  1968 Winter  1968  Winter
# 11726   174.0   69.0  Netherlands  NED  1972 Winter  1972  Winter
#
#                  city          sport                                   event  \
# 92            Atlanta         Rowing  Rowing Men's Lightweight Double Sculls
# 1227           London         Rowing             Rowing Women's Coxed Eights
# 1228   Rio de Janeiro         Rowing         Rowing Women's Quadruple Sculls
# 2099          Beijing         Hockey                   Hockey Women's Hockey
# 2100           London         Hockey                   Hockey Women's Hockey
# 8596           Sydney         Rowing             Rowing Women's Coxed Eights
# 11720          London         Hockey                     Hockey Men's Hockey
# 11724        Grenoble  Speed Skating      Speed Skating Women's 1,500 metres
# 11725        Grenoble  Speed Skating      Speed Skating Women's 3,000 metres
# 11726         Sapporo  Speed Skating      Speed Skating Women's 1,500 metres
#
#         medal   gold  silver  bronze
# 92     Silver  False    True   False
# 1227   Bronze  False   False    True
# 1228   Silver  False    True   False
# 2099     Gold   True   False   False
# 2100     Gold   True   False   False
# 8596   Silver  False    True   False
# 11720  Silver  False    True   False
# 11724  Bronze  False   False    True
# 11725  Bronze  False   False    True
# 11726  Silver  False    True   False

# %%
nb_gold_medal= neth_olympic1.groupby(['year'])['gold'].sum()
nb_gold_medal.head(5)
# Out:
# year
# 1924    0
# 1928    3
# 1932    1
# 1936    1
# 1948    4
# Name: gold, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
nb_gold_medal.plot()
plt.xlabel('années')
plt.ylabel('nb de medals')
plt.title('les medals d or protés par les Irlandians');

# %%
nb_silver_medal= neth_olympic1.groupby(['year'])['silver'].sum()
nb_silver_medal.head(5)
# Out:
# year
# 1924    0
# 1928    2
# 1932    7
# 1936    1
# 1948    0
# Name: silver, dtype: int64

# %%
nb_silver_medal.plot()

plt.xlabel('années')
plt.ylabel('nb de medals')
plt.title('les medals argents protés par les Irlandians');

# %%
nb_bronze_medal= neth_olympic1.groupby(['year'])['bronze'].sum()
nb_bronze_medal.head(5)
# Out:
# year
# 1924    1
# 1928    0
# 1932    0
# 1936    2
# 1948    2
# Name: bronze, dtype: int64

# %%
nb_bronze_medal.plot()

plt.xlabel('années')
plt.ylabel('nb de medals')
plt.title('les medals bronze protés par les Irlandians');

# %% [markdown]
# * Construire une nouvelle dataset

# %%
# build the general dataset Medal/Year
new = { 
   "bronze_medal":nb_bronze_medal,
   "silver_medal":nb_silver_medal ,
   "gold_medal":nb_gold_medal,
   "total_medal":nb_gold_medal+nb_silver_medal+nb_bronze_medal
}

new_df_1 = pd.DataFrame(new).reset_index()

new_df_1.head(5)
# Out:
#    year  bronze_medal  silver_medal  gold_medal  total_medal
# 0  1924             1             0           0            1
# 1  1928             0             2           3            5
# 2  1932             0             7           1            8
# 3  1936             2             1           1            4
# 4  1948             2             0           4            6

# %%
# build the specified dataset Year/City/Medal
new_df_2 = neth_olympic1.groupby(['year','city'])['bronze','silver','gold'].sum().reset_index() # group by city and year 
new_df_2['total_medal'] = new_df_2['gold'] + new_df_2['silver'] + new_df_2['bronze'] # Calculate the total of medals
new_df_2 = new_df_2.rename({'bronze': 'bronze_medal', 'silver': 'silver_medal', 'gold': 'gold_medal'}, axis='columns') # rename the columns 
new_df_2.head(5)
# Out:
#    year         city  bronze_medal  silver_medal  gold_medal  total_medal
# 0  1924        Paris             1             0           0            1
# 1  1928    Amsterdam             0             2           3            5
# 2  1932  Los Angeles             0             7           1            8
# 3  1936       Berlin             2             1           1            4
# 4  1948       London             2             0           4            6

# %% [markdown]
# Le maximum de medals qui etaient prise par holand

# %%
# First method (return the city that has the max number of total medals)
last=new_df_2.loc[new_df_2['total_medal'] == max(new_df_2['total_medal'])]
last
# Out:
#     year    city  bronze_medal  silver_medal  gold_medal  total_medal
# 26  2000  Sydney            23            29          27           79

# %%
# Second method 
new_df_2.iloc[new_df_2['total_medal'].idxmax()]
# Out:
# year              2000
# city            Sydney
# bronze_medal        23
# silver_medal        29
# gold_medal          27
# total_medal         79
# Name: 26, dtype: object

# %%
last.plot(kind='bar')
plt.xlabel('Sydny en 2000')
plt.ylabel('nb de medals')
plt.title('les differents medales portés par les Irlandiens');

# %%
# return the city that has the max number of gold medals
new_df_2.loc[new_df_2['gold_medal'] == max(new_df_2['gold_medal'])]
# Out:
#        city  bronze_medal  silver_medal  gold_medal  total_medal
# 30  Beijing             4            15          39           58
